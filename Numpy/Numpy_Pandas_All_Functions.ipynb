# %% [markdown]
# ----------------
# #### **Author Name :** Muhammad Muneer Hussain
# #### **Linkedin :** [Click Here](https://www.linkedin.com/in/muneer-hussain-ai/)
# #### **Github :** [Click Here](https://github.com/Muhammad-Muneer-Hussain)
# #### **Gmail :** muhammadmuneerhussain85@gmail.com
#
# -----------------------------

# %% [markdown]
# # Pandas_Numpy_Extended
# - Mostly use functions

# %% [markdown]
# ### `np.array()`
#
# Create an array from a Python list or nested lists

# %%
import numpy as np
arr = np.array([1, 2, 3])
arr
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### `np.arange()`
#
# Create evenly spaced values within a range.

# %%
import numpy as np
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %% [markdown]
# ### `np.linspace()`
#
# Create evenly spaced numbers over a specified interval.

# %%
import numpy as np
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %% [markdown]
# ### `np.reshape()`
#
# Change the shape of an array without changing data.

# %%
import numpy as np
arr = np.arange(6).reshape(2, 3)
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# ### `np.ravel()` / `flatten()`
#
# Flatten a multi-dimensional array to 1D.

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
arr.ravel()
# or
arr.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### `np.transpose()` / `.T`
#
# Transpose an array (swap axes).

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
arr.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# ### `np.concatenate()`
#
# Join arrays along an existing axis.

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
np.concatenate([a, b])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### `np.vstack()` / `np.hstack()`
#
# Stack arrays vertically / horizontally.

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
np.vstack([a, b])
np.hstack([a, b])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ### `np.expand_dims()` / `np.squeeze()`
#
# Add or remove dimensions.

# %%
import numpy as np
a = np.array([1,2,3])
np.expand_dims(a, axis=0)
# remove single-dimensional entries
np.squeeze(np.array([[1,2,3]]))
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### `np.sum(axis=)`
#
# Sum elements along an axis (axis=0 column-wise, axis=1 row-wise).

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
np.sum(arr, axis=0)
np.sum(arr, axis=1)
# Out:
# array([ 6, 15])

# %% [markdown]
# ### `np.mean()` / `np.median()` / `np.std()`
#
# Compute mean, median, std deviation (supports axis parameter).

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
np.mean(arr, axis=1)
np.median(arr)
np.std(arr)
# Out:
# np.float64(1.707825127659933)

# %% [markdown]
# ### `np.min()` / `np.max()`
#
# Find min or max value along an axis.

# %%
import numpy as np


arr = np.array([[1,2,3],[4,5,6]])
np.min(arr, axis=0)
np.max(arr, axis=1)
# Out:
# array([3, 6])

# %% [markdown]
# ### `np.argmin()` / `np.argmax()`
#
# Indices of min or max values.

# %%
import numpy as np
arr = np.array([3,1,2])
np.argmin(arr)
np.argmax(arr)
# Out:
# np.int64(0)

# %% [markdown]
# ### `np.unique()`
#
# Return unique values (optionally return counts).

# %%
import numpy as np
arr = np.array([1,2,2,3,1])
np.unique(arr)
np.unique(arr, return_counts=True)
# Out:
# (array([1, 2, 3]), array([2, 2, 1]))

# %% [markdown]
# ### `np.where()`
#
# Return indices or elements meeting a condition.

# %%
import numpy as np
arr = np.array([1,5,2,8,3])
np.where(arr > 3)
# use to select elements
arr[np.where(arr > 3)]
# Out:
# array([5, 8])

# %% [markdown]
# ### `np.sort()`
#
# Return a sorted copy of an array.

# %%
import numpy as np
arr = np.array([3,1,2])
np.sort(arr)
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### `np.dot()` / `np.matmul()`
#
# Matrix multiplication.

# %%
import numpy as np
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
np.dot(A, B)
np.matmul(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# ### `np.eye()` / `np.identity()`
#
# Create identity matrix.

# %%
import numpy as np
np.eye(3)
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### `np.zeros()` / `np.ones()`
#
# Create arrays of zeros / ones.

# %%
import numpy as np
np.zeros((2,3))
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# ### `np.random.rand()` / `np.random.randn()`
#
# Generate random arrays (uniform / normal).

# %%
import numpy as np
np.random.rand(2,3)
np.random.randn(2,3)
# Out:
# array([[-2.54504458, -1.3327953 , -0.26379813],
#        [ 1.51348979, -2.26301239,  0.03441873]])

# %% [markdown]
# ### `np.save()` / `np.load()`
#
# Save/load arrays to .npy format.

# %%
import numpy as np
arr = np.arange(5)
np.save('tmp_array.npy', arr)
np.load('tmp_array.npy')
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# ### `np.genfromtxt()` / `np.savetxt()`
#
# Read/write text data files (CSV, etc.).

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
np.savetxt('tmp.csv', arr, delimiter=',')
np.genfromtxt('tmp.csv', delimiter=',')
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %% [markdown]
# ## Pandas — one function per cell
# Each cell below demonstrates a single Pandas function or closely related pair.

# %% [markdown]
# ### `pd.Series()`
#
# Create a one-dimensional labeled array.

# %%
import pandas as pd
s = pd.Series([10, 20, 30], name='grades')
s
# Out:
# 0    10
# 1    20
# 2    30
# Name: grades, dtype: int64

# %% [markdown]
# ### `pd.DataFrame()`
#
# Create a two-dimensional labeled structure.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2], 'B':[3,4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# ### `pd.read_csv()` / `to_csv()`
#
# Import/export CSV files.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.to_csv('sample.csv', index=False)
pd.read_csv('sample.csv')
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# ### `pd.read_excel()` / `to_excel()`
#
# Import/export Excel files (requires openpyxl/xlrd depending on format).

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.to_excel('sample.xlsx', index=False)
# pd.read_excel('sample.xlsx')  # uncomment if openpyxl is available
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 3
#       1 import pandas as pd
#       2 df = pd.DataFrame({'A':[1,2],'B':[3,4]})
# ----> 3 df.to_excel('sample.xlsx', index=False)
#       4 # pd.read_excel('sample.xlsx')  # uncomment if openpyxl is available
#
# File ~\miniconda3\envs\General_env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\General_env\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)   2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File ~\miniconda3\envs\General_env\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\miniconda3\envs\General_env\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)     66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# ### `pd.read_json()` / `to_json()`
#
# Import/export JSON data.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.to_json('sample.json')
pd.read_json('sample.json')
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# ### `head()` / `tail()`
#
# View first/last n rows.

# %%
import pandas as pd
df = pd.DataFrame({'A':range(10),'B':range(10,20)})
df.head(3)
df.tail(2)
# Out:
#    A   B
# 8  8  18
# 9  9  19

# %% [markdown]
# ### `info()`
#
# Display summary of DataFrame.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3],'B':['x','y','z']})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %% [markdown]
# ### `describe()`
#
# Summary statistics for numeric columns.

# %%
import pandas as pd
df = pd.DataFrame({'num':[1,2,3,4],'cat':['a','b','a','b']})
df.describe()
# Out:
#             num
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %% [markdown]
# ### `dtypes`
#
# Show data types of columns.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2.5],'B':['x','y']})
df.dtypes
# Out:
# A    float64
# B     object
# dtype: object

# %% [markdown]
# ### `shape` / `size`
#
# Shape and total elements of DataFrame.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3]})
df.shape, df.size
# Out:
# ((3, 1), 3)

# %% [markdown]
# ### `empty`
#
# Check if DataFrame is empty.

# %%
import pandas as pd
df = pd.DataFrame()
df.empty
# Out:
# True

# %% [markdown]
# ### `columns` / `index`
#
# Access or rename labels.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1], 'B':[2]})
cols = df.columns
idx = df.index
# rename
df.columns = ['X','Y']
df
# Out:
#    X  Y
# 0  1  2

# %% [markdown]
# ### `select_dtypes()`
#
# Select columns by data type.

# %%
import pandas as pd
df = pd.DataFrame({'num':[1,2], 'txt':['a','b']})
df.select_dtypes(include='number')
# Out:
#    num
# 0    1
# 1    2

# %% [markdown]
# ### `astype()`
#
# Change column data type.

# %%
import pandas as pd
df = pd.DataFrame({'A':['1','2']})
df['A'] = df['A'].astype(int)
df.dtypes
# Out:
# A    int64
# dtype: object

# %% [markdown]
# ### `to_datetime()`
#
# Convert column to datetime.

# %%
import pandas as pd
df = pd.DataFrame({'date':['2020-01-01','2020-02-01']})
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %% [markdown]
# ### `isna()` / `notna()`
#
# Detect missing values.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,None,3]})
df.isna().sum()
df.notna()
# Out:
#        A
# 0   True
# 1  False
# 2   True

# %% [markdown]
# ### `dropna()`
#
# Drop rows/columns with missing values (axis=0 rows, axis=1 columns).

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,None,3],'B':[None,2,3]})
df.dropna()
# drop columns with any NA
# df.dropna(axis=1)
# Out:
#      A    B
# 2  3.0  3.0

# %% [markdown]
# ### `fillna()`
#
# Fill missing values with constant/method.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,None,3],'B':[4,5,None]})
df.fillna(0)
# or use method df.fillna(method='ffill')
# Out:
#      A    B
# 0  1.0  4.0
# 1  0.0  5.0
# 2  3.0  0.0

# %% [markdown]
# ### `replace()`
#
# Replace specific values.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1, -999, 3]})
df.replace({-999: None})
# Out:
#       A
# 0     1
# 1  None
# 2     3

# %% [markdown]
# ### `drop_duplicates()`
#
# Remove duplicate rows.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,1,2],'B':[3,3,4]})
df.drop_duplicates()
# Out:
#    A  B
# 0  1  3
# 2  2  4

# %% [markdown]
# ### `duplicated()`
#
# Find duplicated rows (boolean mask).

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,1,2]})
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %% [markdown]
# ### `sort_values()`
#
# Sort DataFrame by one or more column values.

# %%
import pandas as pd
df = pd.DataFrame({'Name':['b','a','c'],'Age':[30,20,25]})
df.sort_values(by='Age')
# Out:
#   Name  Age
# 1    a   20
# 2    c   25
# 0    b   30

# %% [markdown]
# ### `sort_index()`
#
# Sort by index.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2]}, index=[2,1])
df.sort_index()
# Out:
#    A
# 1  2
# 2  1

# %% [markdown]
# ### `set_index()` / `reset_index()`
#
# Set or reset DataFrame index.

# %%
import pandas as pd
df = pd.DataFrame({'id':[101,102],'val':[1,2]})
df2 = df.set_index('id')
df2.reset_index()
# Out:
#     id  val
# 0  101    1
# 1  102    2

# %% [markdown]
# ### `loc` / `iloc`
#
# Select data by label (`loc`) or position (`iloc`).

# %%
import pandas as pd
df = pd.DataFrame({'A':[10,20,30],'B':[1,2,3]}, index=['x','y','z'])
df.loc['y','A']
df.iloc[1,0]
# Out:
# np.int64(20)

# %% [markdown]
# ### `at` / `iat`
#
# Fast access by label or integer position.

# %%
import pandas as pd
df = pd.DataFrame({'A':[5,6]})
df.at[0,'A']
df.iat[0,0]
# Out:
# np.int64(5)

# %% [markdown]
# ### `query()`
#
# Query rows using an expression string.

# %%
import pandas as pd
df = pd.DataFrame({'Age':[25,35,45]})
df.query('Age > 30')
# Out:
#    Age
# 1   35
# 2   45

# %% [markdown]
# ### `assign()`
#
# Create new columns (returns new DataFrame).

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2]})
df2 = df.assign(B = df['A']*10)
df2
# Out:
#    A   B
# 0  1  10
# 1  2  20

# %% [markdown]
# ### `apply()` / `applymap()`
#
# Apply functions row/column-wise or element-wise.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.apply(np.mean, axis=0)
df.applymap(lambda x: x*2)
# Out:
# C:\Users\MUNEER\AppData\Local\Temp\ipykernel_9192\1818890971.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x*2)
#    A  B
# 0  2  6
# 1  4  8

# %% [markdown]
# ### `map()`
#
# Apply function or dict to Series values.

# %%
import pandas as pd
s = pd.Series(['A','B','A'])
s.map({'A':1,'B':2})
# Out:
# 0    1
# 1    2
# 2    1
# dtype: int64

# %% [markdown]
# ### `groupby()`
#
# Group data for aggregation.

# %%
import pandas as pd
df = pd.DataFrame({'Dept':['HR','HR','IT'],'Salary':[50,60,70]})
df.groupby('Dept')['Salary'].mean()
# Out:
# Dept
# HR    55.0
# IT    70.0
# Name: Salary, dtype: float64

# %% [markdown]
# ### `agg()` / `aggregate()`
#
# Aggregate multiple functions on columns.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3]})
df.agg({'A':['min','max','mean']})
# Out:
#         A
# min   1.0
# max   3.0
# mean  2.0

# %% [markdown]
# ### `transform()`
#
# Transform group data to match original shape.

# %%
import pandas as pd
df = pd.DataFrame({'Dept':['HR','HR','IT'],'Salary':[50,60,70]})
df['Dept_mean'] = df.groupby('Dept')['Salary'].transform('mean')
df
# Out:
#   Dept  Salary  Dept_mean
# 0   HR      50       55.0
# 1   HR      60       55.0
# 2   IT      70       70.0

# %% [markdown]
# ### `pivot_table()`
#
# Create pivot table with aggregation.

# %%
import pandas as pd
df = pd.DataFrame({'Dept':['HR','IT','HR'],'Sales':[10,20,30]})
pd.pivot_table(df, index='Dept', values='Sales', aggfunc='sum')
# Out:
#       Sales
# Dept
# HR       40
# IT       20

# %% [markdown]
# ### `melt()`
#
# Unpivot wide DataFrame to long format.

# %%
import pandas as pd
df = pd.DataFrame({'id':[1,2],'Jan':[10,20],'Feb':[15,25]})
pd.melt(df, id_vars=['id'], var_name='Month', value_name='Sales')
# Out:
#    id Month  Sales
# 0   1   Jan     10
# 1   2   Jan     20
# 2   1   Feb     15
# 3   2   Feb     25

# %% [markdown]
# ### `concat()`
#
# Concatenate DataFrames along axis.

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[1,2]})
df2 = pd.DataFrame({'A':[3,4]})
pd.concat([df1, df2], ignore_index=True)
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# ### `merge()`
#
# SQL-style join of DataFrames.

# %%
import pandas as pd
df1 = pd.DataFrame({'id':[1,2],'v1':[10,20]})
df2 = pd.DataFrame({'id':[2,1],'v2':[30,40]})
pd.merge(df1, df2, on='id')
# Out:
#    id  v1  v2
# 0   1  10  40
# 1   2  20  30

# %% [markdown]
# ### `join()`
#
# Join on index or key column.

# %%
import pandas as pd
df1 = pd.DataFrame({'v1':[1,2]}, index=['a','b'])
df2 = pd.DataFrame({'v2':[3,4]}, index=['a','b'])
df1.join(df2)
# Out:
#    v1  v2
# a   1   3
# b   2   4

# %% [markdown]
# ### `value_counts()`
#
# Frequency of unique values in a Series.

# %%
import pandas as pd
s = pd.Series(['x','y','x','z'])
s.value_counts()
# Out:
# x    2
# y    1
# z    1
# Name: count, dtype: int64

# %% [markdown]
# ### `unique()`
#
# Return unique values of a Series.

# %%
import pandas as pd
s = pd.Series([1,2,2,3])
s.unique()
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### `nunique()`
#
# Count unique values.

# %%
import pandas as pd
s = pd.Series([1,2,2,3])
s.nunique()
# Out:
# 3

# %% [markdown]
# ### `between()`
#
# Select rows within a range.

# %%
import pandas as pd
df = pd.DataFrame({'Score':[50,80,90]})
df[df['Score'].between(60,95)]
# Out:
#    Score
# 1     80
# 2     90

# %% [markdown]
# ### `clip()`
#
# Limit values to a range.

# %%
import pandas as pd
df = pd.DataFrame({'Score':[120,80,-5]})
df['Score'].clip(0,100)
# Out:
# 0    100
# 1     80
# 2      0
# Name: Score, dtype: int64

# %% [markdown]
# ### `where()`
#
# Replace values conditionally.

# %%
import pandas as pd
df = pd.DataFrame({'Score':[50,80,30]})
df['Pass'] = df['Score'].where(df['Score']>50, 'Fail')
df
# Out:
#    Score  Pass
# 0     50  Fail
# 1     80    80
# 2     30  Fail

# %% [markdown]
# ### `sample()`
#
# Return random sample of rows.

# %%
import pandas as pd
df = pd.DataFrame({'A':range(10)})
df.sample(n=3)
# Out:
#    A
# 8  8
# 1  1
# 5  5

# %% [markdown]
# ### `corr()` / `cov()`
#
# Correlation / covariance matrix.

# %%
import pandas as pd
df = pd.DataFrame({'x':[1,2,3],'y':[1,4,9]})
df.corr()
df.cov()
# Out:
#      x          y
# x  1.0   4.000000
# y  4.0  16.333333

# %% [markdown]
# ### `sum()` / `mean()` / `median()`
#
# Compute summary statistics.

# %%
import pandas as pd
df = pd.DataFrame({'Sales':[10,20,30]})
df['Sales'].sum()
df['Sales'].mean()
df['Sales'].median()
# Out:
# 20.0

# %% [markdown]
# ### `std()` / `var()`
#
# Standard deviation and variance.

# %%
import pandas as pd
df = pd.DataFrame({'Sales':[10,20,30]})
df['Sales'].std()
df['Sales'].var()
# Out:
# 100.0

# %% [markdown]
# ### `mode()`
#
# Most frequent value.

# %%
import pandas as pd
df = pd.DataFrame({'City':['A','B','A']})
df['City'].mode()
# Out:
# 0    A
# Name: City, dtype: object

# %% [markdown]
# ### `idxmax()` / `idxmin()`
#
# Index of max / min value.

# %%
import pandas as pd
df = pd.DataFrame({'Sales':[5,9,3]})
df['Sales'].idxmax()
df['Sales'].idxmin()
# Out:
# 2

# %% [markdown]
# ### `pipe()`
#
# Chain operations in function pipelines.

# %%
import pandas as pd
def add_col(df):
    return df.assign(Total = df['A'] + df['B'])
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.pipe(add_col)
# Out:
#    A  B  Total
# 0  1  3      4
# 1  2  4      6

# %% [markdown]
# ### `eval()`
#
# Evaluate expressions in DataFrame.

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2],'B':[3,4]})
df.eval('Total = A + B')
df
# Out:
#    A  B
# 0  1  3
# 1  2  4
