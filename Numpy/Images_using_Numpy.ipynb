# %% [markdown]
# # from skimage import data
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Load an example image from scikit-image
# img_array = np.array(data.astronaut())  # Example astronaut image
# plt.imshow(img_array)
# plt.axis("off")
# plt.title("Sample Image")

# %%
img_array
# Out:
# array([[[154, 147, 151],
#         [109, 103, 124],
#         [ 63,  58, 102],
#         ...,
#         [127, 120, 115],
#         [120, 117, 106],
#         [125, 119, 110]],
#
#        [[177, 171, 171],
#         [144, 141, 143],
#         [113, 114, 124],
#         ...,
#         [127, 118, 112],
#         [124, 115, 108],
#         [121, 116, 105]],
#
#        [[201, 194, 193],
#         [182, 178, 175],
#         [168, 165, 164],
#         ...,
#         [128, 120, 117],
#         [126, 116, 112],
#         [124, 114, 109]],
#
#        ...,
#
#        [[186, 170, 176],
#         [186, 170, 177],
#         [183, 168, 170],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   1],
#         [  0,   0,   0]],
#
#        [[183, 169, 170],
#         [182, 167, 171],
#         [185, 164, 176],
#         ...,
#         [  0,   0,   1],
#         [  1,   1,   1],
#         [  0,   0,   0]],
#
#        [[184, 167, 172],
#         [183, 165, 169],
#         [180, 162, 171],
# ...

# %%
# Out:
# array([[[154, 147, 151],
#         [109, 103, 124],
#         [ 63,  58, 102],
#         ...,
#         [127, 120, 115],
#         [120, 117, 106],
#         [125, 119, 110]],
#
#        [[177, 171, 171],
#         [144, 141, 143],
#         [113, 114, 124],
#         ...,
#         [127, 118, 112],
#         [124, 115, 108],
#         [121, 116, 105]],
#
#        [[201, 194, 193],
#         [182, 178, 175],
#         [168, 165, 164],
#         ...,
#         [128, 120, 117],
#         [126, 116, 112],
#         [124, 114, 109]],
#
#        ...,
#
#        [[186, 170, 176],
#         [186, 170, 177],
#         [183, 168, 170],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   1],
#         [  0,   0,   0]],
#
#        [[183, 169, 170],
#         [182, 167, 171],
#         [185, 164, 176],
#         ...,
#         [  0,   0,   1],
#         [  1,   1,   1],
#         [  0,   0,   0]],
#
#        [[184, 167, 172],
#         [183, 165, 169],
#         [180, 162, 171],
# ...

# %%
img_array
print(img_array.shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# **`skimage`**: Provides sample images; data.astronaut() loads an example astronaut image.
#
# **`numpy:`** Handles array operations, which we use to manipulate the image as a matrix.
#
# **`matplotlib.pyplot`**: Used to display images for visualization.

# %% [markdown]
# # Cropping the Image

# %%
# Crop a 100x100 region from the top-left corner
cropped_img = img_array[:187, :243]  # Selects rows and columns up to index 100
plt.imshow(cropped_img)
plt.title("Cropped Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(242.5), np.float64(186.5), np.float64(-0.5))

# %% [markdown]
# **Crop Image:** `img_array[:100, :100]` selects the top-left 100 rows and 100 columns, creating a 100x100 pixel crop.
#
#
# **Display Cropped Image:** The cropped image is displayed, and axes are hidden for clarity.

# %% [markdown]
# # Remove the Red Channel

# %%
img_no_red = img_array.copy()
img_no_red[:, :, 2] = 0
plt.imshow(img_no_red)
plt.title("Image without Red Channel")
plt.axis('off')
plt.show()

# %% [markdown]
# **Create a Copy:** `img_array.copy()` creates a copy of the image to avoid modifying the original.
#
#
# **Remove Red Channel:** `img_no_red[:, :, 0] = 0` sets the red channel to 0 for all pixels.
#
#
# `[:, :, 0]` selects the first color channel (red) across all rows and columns.
#
# Assigning 0 to this channel removes the red tones, resulting in an image where only green and blue colors contribute to each pixel.
#
#
# **Display Modified Image:** The altered image without the red channel is shown.

# %%
# Flip the Image Horizontally
flipped_img = np.flip(img_array, axis=0)  # Flips the image horizontally
plt.imshow(flipped_img)
plt.title("Horizontally Flipped Image")
plt.axis('off')
plt.show()

# %% [markdown]
# **Horizontal Flip:** `np.flip(img_array, axis=1)` flips the image along the horizontal axis.
#
# `axis=0` specifies the direction of the flip (left to right).
#
# Every pixel in each row is reversed, creating a mirror image.

# %%
# Rotate the Image by 90 Degrees
rotated_img = np.rot90(img_array)  # Rotates the image 90 degrees counterclockwise
plt.imshow(rotated_img)
plt.title("Rotated Image (90 Degrees)")
plt.axis('off')
plt.show()

# %% [markdown]
# **Rotate Image:** np.rot90(img_array) rotates the image by 90 degrees counterclockwise.
#
# `np.rot90` effectively switches the rows with columns and flips the array along one dimension.
#
# The result is a rotated version of the image.
#
# Display Rotated Image: The rotated image is shown.

# %%
# Convert the Image to Grayscale
grayscale_img = 0.2989 * img_array[:, :, 0] + 0.5870 * img_array[:, :, 1] + 0.1140 * img_array[:, :, 2]
plt.imshow(grayscale_img, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Grayscale Conversion:
# To convert an RGB image to grayscale, we use a weighted sum of the RGB channels.
#
# Formula: 0.2989 * R + 0.5870 * G + 0.1140 * B
#
# 0.2989, 0.5870, and 0.1140 are weights representing human sensitivity to each color.
#
# Red contributes the least to brightness, while green has the highest contribution.
#
# `img_array[:, :, 0]` accesses the red channel, `img_array[:, :, 1]` accesses the green, and img_array[:, :, 2] accesses the blue.
#
# **Display Grayscale Image:** `plt.imshow(grayscale_img, cmap='gray')` shows the grayscale image with cmap='gray' to ensure it’s rendered in shades of gray.
